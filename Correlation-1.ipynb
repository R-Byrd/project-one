# %%
import pandas as pd
import numpy as np
import json
from pathlib import Path
import matplotlib.pyplot as plt
import os

# %%
netflix_cleaned_data = Path('Resources/updated_cleaned_ended_netflix_shows_05_15_V3.csv')
netflix_cleaned_df = pd.read_csv(netflix_cleaned_data, encoding="ISO-8859-1")


#making visualizations directly from the csv files

# %%
netflix_cleaned_df.describe()
netflix_cleaned_df.info()
#breaking the data down to see the number in each parameter
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1291 entries, 0 to 1290
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          1291 non-null   object
#  1   Seasons        1291 non-null   int64
#  2   Cancelled      1291 non-null   int64
#  3   Genre          1291 non-null   object
#  4   Country        671 non-null    object
#  5   Type           1291 non-null   object
#  6   Premiere Year  1291 non-null   int64
#  7   Finale Year    1289 non-null   float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 80.8+ KB

# %%
number_of_seasons = netflix_cleaned_df['Seasons'].value_counts()
print(number_of_seasons)

#extracted the data from the dataframe to look at how many shows had many seasons.
# Out:
# Seasons
# 1    965
# 2    178
# 3     83
# 4     30
# 5     16
# 6     12
# 7      4
# 8      3
# Name: count, dtype: int64

# %%
number_of_seasons = netflix_cleaned_df['Genre'].value_counts().sort_index()
print(genres)
# Out:
# ['Action', 'Crime', 'Horror', 'Romantic', 'Comedy']

# %%
#creating visualizations to show the correlation between number of seasons and genres?
number_of_seasons.plot(kind='line')
plt.xticks(rotation=45)
plt.title("Correlation between Number of Shows and Genres")
plt.xlabel("Different Genres")
plt.ylabel("Number of Shows")
plt.show()

# %%
#Question, What is the correlation between the genre and number of seasons?

y_axis = np.arange(len(number_of_seasons))
tick_locations = [value+0.4 for value in x_axis]
plt.figure(figsize=(10,4))
number_of_seasons.plot(kind='bar')
plt.title("Genres vs. Seasons")
plt.xlabel("Different Genres")
plt.ylabel("Number of Seasons")
plt.show()
#what are the numbers representing

# %%
#Question, What is the correlation between the year and number of cancellations?
'animation', 'anime series', 'british tv','children', 'comedies','crime tv', 'documentary', 'docuseries', 'horror', 'international tv', 'kids', 'mockumentary','reality tv','stand-up','tv action','tv comedy','tv dramas','thriller'
cancellations_df = netflix_cleaned_df.loc[netflix_cleaned_df['Seasons'] == 1 ]
cancellations_per_year = cancellations_df['Premiere Year'].value_counts().sort_index()
print(cancellations_per_year)
plt.figure(figsize=(10, 6))
cancellations_per_year.plot(kind='pie')
plt.title('Shows Cancelled after 1 Season')
plt.xlabel('Premiere Year')
plt.ylabel('Number of Ended Shows')
plt.show()
# Out:
# Premiere Year
# 2013      2
# 2014      5
# 2015      6
# 2016     15
# 2017     33
# 2018     87
# 2019    132
# 2020    198
# 2021    201
# 2022    250
# 2023     36
# Name: count, dtype: int64

# %%
labels =[2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
sizes = [20, 50, 60, 65, 70, 75, 80, 85, 90, 95, 100]
colors = ['orange', 'red', 'white', 'yellow', 'pink','purple','green','lightcoral','lightskyblue','lightgreen','grey']
plt.pie(sizes, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=20)
plt.title('Shows Cancelled after 1 Season')
plt.xlabel('Premiere Year')
plt.ylabel('Number of Ended Shows')
plt.axis("equal")
plt.show()
