# %%
import pandas as pd
import numpy as np
import json
from pathlib import Path
import matplotlib.pyplot as plt
import os


netflix_data = Path("Resources/updated_cleaned_ended_netflix_shows_05_15_V3.csv")

# %%
#Reading csv file
netflix_data_df = pd.read_csv(netflix_data, encoding="ISO-8859-1")
netflix_data_df.columns
# Out:
# Index(['Title', 'Seasons', 'Cancelled', 'Genre', 'Country', 'Type',
#        'Premiere Year', 'Finale Year'],
#       dtype='object')

# %%
netflix_data_df.describe()
# Out:
#            Seasons    Cancelled  Premiere Year  Finale Year
# count  1291.000000  1291.000000    1291.000000  1289.000000
# mean      1.467080     0.731216    2019.752905  2020.216447
# std       1.021229     0.443499       2.006612     1.742466
# min       1.000000     0.000000    2012.000000  2013.000000
# 25%       1.000000     0.000000    2019.000000  2019.000000
# 50%       1.000000     1.000000    2020.000000  2020.000000
# 75%       2.000000     1.000000    2021.000000  2022.000000
# max       8.000000     1.000000    2023.000000  2023.000000

# %%
# Count the number of TV shows per year
shows_per_year = netflix_data_df['Premiere Year'].value_counts().sort_index()

# Print the results
print(shows_per_year)

# Plot the number of TV shows per year
plt.figure(figsize=(10, 6))
shows_per_year.plot(kind='bar')
plt.title('Number of TV Shows per Year')
plt.xlabel('Premiere Year')
plt.ylabel('Number of TV Shows')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# Premiere Year
# 2012      1
# 2013      6
# 2014     10
# 2015     30
# 2016     44
# 2017     80
# 2018    150
# 2019    196
# 2020    251
# 2021    229
# 2022    258
# 2023     36
# Name: count, dtype: int64

# %%
# Filter the DataFrame to include only canceled shows (Season Canceled == 1)
canceled_shows_df = netflix_data_df.loc[netflix_data_df['Season Canceled'] == 1]

# Count the number of canceled shows per premiere year
canceled_shows_per_year = canceled_shows_df['Premiere Year'].value_counts().sort_index()

# Print the results
print(canceled_shows_per_year)

# Plot the number of canceled shows per premiere year
plt.figure(figsize=(10, 6))
plt.plot(canceled_shows_per_year.index, canceled_shows_per_year.values, marker='o', linestyle='-', color='b')
plt.title('Number of Netflix TV Shows Canceled After 1 Season')
plt.xlabel('Premiere Year')
plt.ylabel('Number of Canceled TV Shows')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Format the x-axis labels to remove the decimal
plt.xticks(canceled_shows_per_year.index, [int(label) for label in canceled_shows_per_year.index], rotation=45)

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Jessi\anaconda3\envs\dev\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Season Canceled'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Filter the DataFrame to include only canceled shows (Season Canceled == 1)
# ----> 2 canceled_shows_df = netflix_data_df.loc[netflix_data_df['Season Canceled'] == 1]
#       4 # Count the number of canceled shows per premiere year
#       5 canceled_shows_per_year = canceled_shows_df['Premiere Year'].value_counts().sort_index()
#
# File c:\Users\Jessi\anaconda3\envs\dev\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\Jessi\anaconda3\envs\dev\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Season Canceled'

# %%
# Filter the DataFrame to include only canceled shows (Season Canceled == 1)
canceled_shows_df = netflix_data_df.loc[netflix_data_df['Seasons'] == 1 ]

# Count the number of canceled shows per finale year
canceled_shows_per_year = canceled_shows_df['Premiere Year'].value_counts().sort_index()

# Print the results
print(canceled_shows_per_year)

# Plot the number of canceled shows per finale year
plt.figure(figsize=(10, 6))
canceled_shows_per_year.plot(kind='bar')
plt.title('Number of Netflix TV Shows ended after 1 Season')
plt.xlabel('Premiere Year')
plt.ylabel('Number of Ended TV Shows')
plt.xticks(rotation=45)
plt.grid(axis='y')


# Format the x-axis labels to remove the decimal
ax.set_xticklabels([int(label.get_text().replace('.0', '')) for label in ax.get_xticklabels()])

# Display the plot
plt.show()
# Out:
# Premiere Year
# 2013      2
# 2014      5
# 2015      6
# 2016     15
# 2017     33
# 2018     87
# 2019    132
# 2020    198
# 2021    201
# 2022    250
# 2023     36
# Name: count, dtype: int64
